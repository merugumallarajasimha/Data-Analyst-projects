# %% [markdown]
# # IMPORTING DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C://Users//merug//Desktop//Excel project//Raw_Dataset//customer_shopping_behavior.csv")
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# # FILLING MISSING VALUES

# %%
data.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
data['Review Rating']=data.groupby("Category")['Review Rating'].transform(lambda x:x.fillna(x.median()))

# %%
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
data.columns=data.columns.str.lower()
data.columns=data.columns.str.replace(" ","_")

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
data.columns=data.columns.str.replace("purchase_amount_(usd)","purchase_amount")
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
data["age"].max()
# Out:
# 70

# %%
data['age'].min()
# Out:
# 18

# %%
labels=['Young','adult','middle-aged','senior']  
data['age_group']=pd.qcut(data['age'],q=4,labels=labels)

# %%
print(data[["age_group",'age']])
# Out:
#         age_group  age
# 0     middle-aged   55
# 1           Young   19
# 2     middle-aged   50
# 3           Young   21
# 4     middle-aged   45
# ...           ...  ...
# 3895        adult   40
# 3896  middle-aged   52
# 3897  middle-aged   46
# 3898        adult   44
# 3899  middle-aged   52
#
# [3900 rows x 2 columns]

# %%
data['frequency_of_purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
new_col={
    'Fortnightly': 14,
    'Weekly':7,
    'Annually':365,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Monthly':30,
    'Every 3 Months': 90
}
data['frequency_of_days']= data['frequency_of_purchases'].map(new_col)

# %%
data[['frequency_of_days','frequency_of_purchases']]
# Out:
#       frequency_of_days frequency_of_purchases
# 0                    14            Fortnightly
# 1                    14            Fortnightly
# 2                     7                 Weekly
# 3                     7                 Weekly
# 4                   365               Annually
# ...                 ...                    ...
# 3895                  7                 Weekly
# 3896                 14              Bi-Weekly
# 3897                 90              Quarterly
# 3898                  7                 Weekly
# 3899                 90              Quarterly
#
# [3900 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group',
#        'frequency_of_days'],
#       dtype='object')

# %%
data['discount_applied']==data['promo_code_used']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3895    True
# 3896    True
# 3897    True
# 3898    True
# 3899    True
# Length: 3900, dtype: bool

# %%
data.drop(columns=['promo_code_used'],inplace=True)

# %%
data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'frequency_of_days'],
#       dtype='object')

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus  # Helps handle the '@' in your password

# 1. Setup your specific credentials
# We use quote_plus to safely handle the '@' symbols in 'R@j@simh@123'
password = quote_plus("R@j@simh@123") 
db_name = "project_data"  # Make sure you created this database in Workbench first!

# 2. Create the connection engine
# Format: mysql+pymysql://username:password@host/database_name
connection_string = f"mysql+pymysql://root:{password}@localhost/{db_name}"
engine = create_engine(connection_string)

# 3. Export your dataframe (named 'data') to SQL
try:
    # This will create a table named 'my_project_table' in MySQL
    data.to_sql(name='my_project_table', con=engine, if_exists='replace', index=False)
    print("✅ Success! Your 'data' has been exported to MySQL Workbench.")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ✅ Success! Your 'data' has been exported to MySQL Workbench.
